# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.colors as colors
from matplotlib.mlab import bivariate_normal

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

img = mpimg.imread('../resources/text.jpg')

# %%
class preprocessor:
    def __init__(self):
        self.img = 0
        self.vimg = 0
    def vsegmentation(self, img):
        self.vimg = img
        blackline = np.zeros(shape = (1,img.shape[1],3))
        for i in range(img.shape[0]):
            if np.mean(img[i]) < 254:
                vimg[i] = blackline
    def vsegmentation(self, img):
        self.vimg = img
        blackline = np.zeros(shape = (1,img.shape[1],3))
        for i in range(img.shape[0]):
            if np.mean(img[i]) < 254:
                vimg[i] = blackline

# %%
prep = preprocessor()

# %%
prep.vsegmentation(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-127d211fce2e> in <module>()
# ----> 1 prep.vsegmentation(img)
#       2
#
# <ipython-input-75-de1ae0ad2067> in vsegmentation(self, img)
#      14         for i in range(img.shape[0]):
#      15             if np.mean(img[i]) < 254:
# ---> 16                 vimg[i] = blackline
#      17
#
# NameError: global name 'vimg' is not defined

# %%
plt.imshow(img)
plt.show()
